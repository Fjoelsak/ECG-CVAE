# %%
# !git clone https://github.com/Fjoelsak/ECG-CVAE.git
# %cd ECG-CVAE

# %%
import sys
sys.path.append("/content/ECG-CVAE")

# %%
# !wget -O /content/ST.npy "https://github.com/Fjoelsak/ECG-CVAE/releases/download/v0.0.1/ST.npy"

# %%
# %run scripts/train_channel.py --data-path /content/ST.npy
